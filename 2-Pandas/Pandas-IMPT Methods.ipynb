# %%
Pandas is a Python package providing fast, flexible, and expressive data structures
designed to make working with 'relationa' or 'labeled' data both easy and intuitive.

It aims to be the fundamental high-level building block
for doing practical, real world data analysis in Python.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Pandas Methods:-

# %% [markdown]
# ###### 1. VIEWING/INSPECTING DATA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 2. SELECTION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 3. DATA CLEANING

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 4. FILTER,SORT & GROUP BY

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 5. JOIN/COMBINE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 6. STATISTICS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 7. IMPORTING DATA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### 8. EXPORTING DATA

# %% [markdown]
# ![image.png](attachment:image.png)
